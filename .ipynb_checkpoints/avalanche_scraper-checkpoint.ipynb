# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from time import sleep

# store in dictionary for starters
data = {}

# %%
current = "https://www.nwac.us/avalanche-forecast/current/mt-hood/"
r = requests.get(current)
sup = BeautifulSoup(r.content, "html5lib")

# %%
ps = sup.find(id="problems")
l = ps.find_all(class_='problem')
for e in l:
    print(e.attrs)
# Out:
# {'class': ['problem', 'wind-slab']}
# {'class': ['problem', 'loose-wet']}

# %%
def extract(r):
    row = {}

    soup = BeautifulSoup(r.content, "html5lib")
    elevs = soup.find(id="elevation-levels")
    problem_section = soup.find(id="problems")
    problem_tags = problem_section.find_all(class_="problem", recursive=False)
    discussion = soup.find(id='discussion').contents
    
    problems = []
    sizes = []
    likelihoods = []
    octagons = []
    
    for div in problem_tags:
        # print(div.attrs)
        problems.append(div.attrs['class'][1])
        sizes.append(div.find(class_='problem-sizes').attrs['src'])
        likelihoods.append(div.find(class_='problem-likelihood').attrs['src'])
        octagons.append(div.find(class_='problem-octagon').attrs['src'])

    row['problems'] = problems
    row['sizes'] = sizes
    row['likelihoods'] = likelihoods
    row['octagons'] = octagons
    row['discussion'] = discussion
    
    issued = elevs.contents[1].contents[1].string.strip().strip('Issued: ')

    for tag in ["treeline-above", "treeline-near", "treeline-below"]:
        el = elevs.find(id=tag)
        danger = el.contents[3].contents[5].h4.string
        # print(tag, danger)
        row[tag] = danger

    print('\r' + str(row['problems']))
    return issued, row

# extract()

# %%
ex = extract(requests.get(current))
# Out:
# [['wind-slab', 'loose-wet']]

# %%
first_forecast = "https://www.nwac.us/avalanche-forecast/avalanche-region-forecast/73/mt-hood/"
fake_forecast = "https://www.nwac.us/avalanche-forecast/avalanche-region-forecast/3623/mt-hood/"
# url to format, 73 - 3900 ?:
url_base = "https://www.nwac.us/avalanche-forecast/avalanche-region-forecast/{}/mt-hood/"

# %%
for i in range(192, 4000):
# for i in range(73, 75):
    url = url_base.format(i)
    r = requests.get(url)
    print('\r' + str(i) + ' ' + str(r.status_code))
    if r.status_code == 404:
        continue
    else:
        # be nice to server
        sleep(.5)

    try:
        issued, row = extract(r)
        data[issued] = row
    except AttributeError:
        continue
# Out:
# 192 200
# ['wind-slab']
# 193 200
# ['wind-slab']
# 194 404
# 195 404
# 196 404
# 197 404
# 198 200
# ['wind-slab']
# 199 200
# ['wind-slab']
# 200 200
# ['wind-slab']
# 201 200
# 202 404
# 203 200
# ['wind-slab']
# 204 404
# 205 404
# 206 200
# 207 200
# ['wind-slab']
# 208 200
# 209 200
# ['wind-slab', 'storm-slabs']
# 210 200
# ['wind-slab']
# 211 200
# ['wind-slab']
# 212 200
# 213 200
# ['wind-slab', 'storm-slabs']
# 214 404
# 215 404
# 216 200
# ['wind-slab']
# 217 200
# ['wind-slab']
# 218 200
# ['wind-slab']
# 219 200
# ['wind-slab']
# 220 200
# ['wind-slab']
# 221 200
# ['wind-slab', 'loose-wet']
# 222 200
# ['wind-slab', 'loose-wet']
# 223 404
# 224 404
# 225 200
# ['wind-slab', 'loose-wet']
# 226 200
# ['wind-slab', 'loose-wet']
# 227 200
# ['wind-slab', 'loose-wet']
# 228 404
# 229 404
# 230 200
# ['wind-slab', 'loose-wet']
# 231 200
# ['wind-slab']
# 232 200
# ['wind-slab']
# 233 200
# ['wind-slab']
# 234 200
# ['wind-slab']
# 235 200
# ['wind-slab']
# 236 200
# ['wind-slab']
# 237 200
# ['wind-slab']
# 238 200
# ['wind-slab']
# 239 404
# 240 404
# 241 404
# 242 404
# 243 200
# ['wind-slab', 'cornices']
# 244 200
# ['wind-slab']
# 245 200
# ['wind-slab']
# 246 200
# ['cornices', 'wind-slab']
# 247 404
# 248 404
# 249 404
# 250 404
# 251 200
# ['wind-slab']
# 252 404
# 253 404
# 254 404
# 255 200
# ['wind-slab']
# 256 200
# ['wind-slab']
# 257 200
# ['wind-slab']
# 258 200
# ['wind-slab']
# 259 200
# ['wind-slab']
# 260 200
# ['storm-slabs']
# 261 404
# 262 404
# 263 200
# ['storm-slabs']
# 264 200
# ['storm-slabs']
# 265 200
# ['wind-slab', 'storm-slabs']
# 266 200
# ['wind-slab', 'storm-slabs']
# 267 200
# ['wind-slab', 'storm-slabs']
# 268 200

# %%
data
# Out:
# {'10:57 AM PST Saturday, December 21, 2013': {'discussion': ['\n            ',
#    <div class="forecast-snowpack" id="slider1-title" style="display: none">
#                    <h3>Recent images from NWAC:</h3>
#                </div>,
#    '\n            ',
#    ' Jssor Slider Begin ',
#    '\n            ',
#    ' You can move inline styles to css file or css block. ',
#    '\n            ',
#    <div id="slider1_container" style="position: relative; top: 0px; left: 0px; width: 809px; height: 150px; overflow: hidden; display: none;">
#                    <!-- Loading Screen -->
#                    <div style="position: absolute; top: 0px; left: 0px;" u="loading">
#                        <div style="filter: alpha(opacity=70); opacity:0.7; position: absolute; display: block;
#                            background-color: #000; top: 0px; left: 0px; width: 100%;height:100%;">
#                        </div>
#                        <div style="position: absolute; display: block; background: url(../../../static/images/loading.gif) no-repeat center center;
#                            top: 0px; left: 0px;width: 100%;height:100%;">
#                        </div>
#                    </div>
#                    <!-- Slides Container -->
#                    <div id="nwacus_feed" style="cursor: move; position: absolute; left: 0px; top: 0px; width: 809px; height: 150px; overflow: hidden;" u="slides">
#                    </div>
#
#                    <!-- Bullet Navigator Skin Begin -->
#                    <!-- bullet navigator container -->
#                    <div class="jssorb03" style="position: absolute; bottom: 4px; right: 6px;" u="navigator">
#                        <!-- bullet navigator item prototype -->
#                        <div style="position: absolute; width: 21px; height: 21px; text-align:center; line-height:21px; color:white; font-size:12px;" u="prototype">
#                            <div u="numbertemplate"></div>
#                        </div>
#                    </div>
#                    <!-- Bullet Navigator Skin End -->
#                    <!-- Arrow Navigator Skin Begin -->
#                    <!-- Arrow Left -->
#                    <span class="jssora03l" style="width: 55px; height: 55px; top: 123px; left: 8px;" u="arrowleft">
#                    </span>
#                    <!-- Arrow Right -->
#                    <span class="jssora03r" style="width: 55px; height: 55px; top: 123px; right: 8px" u="arrowright">
#                    </span>
#                    <!-- Arrow Navigator Skin End -->
#                </div>,
#    '\n            ',
#    ' Jssor Slider End ',
#    '\n            ',
#    <h2>Snowpack Analysis:</h2>,
#    '\n            ',
#    <p>UPDATED SATURDAY MORNING FOR FREEZING RAIN SEEN AT MT HOOD MEADOWS - SEE FORECAST BELOW</p>,
#    '\n\n',
#    <p>Warm weather last weak created another strong crust layer in most areas. Light amounts of low density some as well as some surface hoar formation occurred over the past few days. This has set the stage for the strong storm that moved through the region Friday. The latest strong storm began with light snowfall at very cold temperatures early Friday, adding to the weak snow overlying a strong crust. This weak near surface snow has been loaded by moderate to heavy amounts of snow at warming temperatures creating unstable conditions.</p>,
#    '\n\n',
#    <p>Friday morning control routes at Mt Baker Ski area were releasing sensitive ski triggered wind slabs on exposed northerly facing terrain in the Mt Baker area ranging up to 30 cm (1 foot). By mid-morning Friday additional loading had built further very sensitive wind slab layers.</p>,
#    '\n\n',
#    <p>The warming and heavy precipitation rates have tipped the balance in many areas given the weak underlying snow all atop of firm crust layers. </p>,
#    '\n\n',
#    <p>There has been a variety of snow crystal types reported falling through the day Friday, ranging from sleet, mixed rain and snow, graupel other unknown grains. The Crystal Mountain area reported a new crust layer forming by midday to the top of the ridges as a result of temperatures in the mid 30's and mixed precipitation forms. </p>,
#    '\n\n',
#    <p>As a result of high variability in temperatures as well as precipitation types <span style="line-height: 1.6em;">experienced</span><span style="line-height: 1.6em;"> </span><span style="line-height: 1.6em;">during Friday's storm, expect an equally wide variety of local snow stability and plan your routes with a high degree of flexibility based on local conditions. Expect to encounter n</span><span style="line-height: 1.6em;">ew wind slab layers as well as storm slabs and persistent slabs, especially in areas receiving the greatest amounts of storm precipitation, such as the volcanic peaks and central WA Cascade Passes. </span><span style="line-height: 1.6em;"> </span></p>,
#    '\n\n',
#    <p><span style="line-height: 1.6em;">Shallow snow cover is limiting the avalanche danger at lower elevations in many areas.</span></p>,
#    '\n\n            ',
#    <div class="forecast-detailed">
#                    <h2>Detailed Forecast for Saturday:</h2>
#                    <p>Light rain or snow showers should end Saturday morning giving way to mostly cloudy conditions. Moderate ridge top winds should persist Saturday. This should allow for slow settlement of newly formed unstable layers, however some new wind transport along ridges may maintain or continue to build wind slabs below ridges.</p>
#
#    <p>Expect to find a wide variety of local snow conditions and plan accordingly with flexibility in mind.</p>
#
#    <p><u><strong>Update Saturday morning</strong></u> - the Mt Hood Meadows ski patrol reports a 1" thick freezing rain crust on Saturday morning throughout the ski area. This will be locking in the snowpack (and cause terrible skiing) and cause a low danger in that area. It is uncertain on Saturday morning how widespread the freezing rain was at Mt Hood. Any areas that have this crust should have a low avalanche danger.</p>
#
#    <p> </p>
#
#                </div>,
#    '\n        '],
#   'likelihoods': ['https://d22fgw9k2fjwhz.cloudfront.net/media/images/likelihood_images/likelihood-33.png',
#    'https://d22fgw9k2fjwhz.cloudfront.net/media/images/likelihood_images/likelihood-33.png'],
#   'octagons': ['/avalanche-forecast/octagon/problem/229.png',
#    '/avalanche-forecast/octagon/problem/230.png'],
#   'problems': ['wind-slab', 'storm-slabs'],
#   'sizes': ['https://d22fgw9k2fjwhz.cloudfront.net/media/images/size_images/size-12.png',
#    'https://d22fgw9k2fjwhz.cloudfront.net/media/images/size_images/size-12.png'],
#   'treeline-above': 'Considerable',
#   'treeline-below': 'Considerable',
#   'treeline-near': 'Considerable'},
#  '2:36 PM PST Tuesday, December 10, 2013': {'discussion': ['\n            ',
#    <div class="forecast-snowpack" id="slider1-title" style="display: none">
#                    <h3>Recent images from NWAC:</h3>
#                </div>,
#    '\n            ',
#    ' Jssor Slider Begin ',
#    '\n            ',
#    ' You can move inline styles to css file or css block. ',
#    '\n            ',
#    <div id="slider1_container" style="position: relative; top: 0px; left: 0px; width: 809px; height: 150px; overflow: hidden; display: none;">
#                    <!-- Loading Screen -->
#                    <div style="position: absolute; top: 0px; left: 0px;" u="loading">
#                        <div style="filter: alpha(opacity=70); opacity:0.7; position: absolute; display: block;
#                            background-color: #000; top: 0px; left: 0px; width: 100%;height:100%;">
#                        </div>
#                        <div style="position: absolute; display: block; background: url(../../../static/images/loading.gif) no-repeat center center;
#                            top: 0px; left: 0px;width: 100%;height:100%;">
#                        </div>
#                    </div>
#                    <!-- Slides Container -->
#                    <div id="nwacus_feed" style="cursor: move; position: absolute; left: 0px; top: 0px; width: 809px; height: 150px; overflow: hidden;" u="slides">
#                    </div>
#
#                    <!-- Bullet Navigator Skin Begin -->
#                    <!-- bullet navigator container -->
#                    <div class="jssorb03" style="position: absolute; bottom: 4px; right: 6px;" u="navigator">
#                        <!-- bullet navigator item prototype -->
#                        <div style="position: absolute; width: 21px; height: 21px; text-align:center; line-height:21px; color:white; font-size:12px;" u="prototype">
#                            <div u="numbertemplate"></div>
#                        </div>
#                    </div>
#                    <!-- Bullet Navigator Skin End -->
#                    <!-- Arrow Navigator Skin Begin -->
#                    <!-- Arrow Left -->
#                    <span class="jssora03l" style="width: 55px; height: 55px; top: 123px; left: 8px;" u="arrowleft">
#                    </span>
#                    <!-- Arrow Right -->
#                    <span class="jssora03r" style="width: 55px; height: 55px; top: 123px; right: 8px" u="arrowright">
#                    </span>
#                    <!-- Arrow Navigator Skin End -->
#                </div>,
#    '\n            ',
#    ' Jssor Slider End ',
#    '\n            ',
#    <h2>Snowpack Analysis:</h2>,
#    '\n            ',
#    <p>The last significant rain and snowfall occurred on December 1st and 2nd when most NWAC weather stations recorded 3-5 inches of precipitation and the Mt Hood area receiving over 10 inches of water. Much of this fell as rain at mid and lower elevations with higher terrain receiving 1-2 feet of snow. </p>,
#    '\n\n',
#    <p>The last warm storm in early December helped form a very strong crust layer with initially very good bonding of the new snow to the forming crust. There was little avalanche activity following this storm with colder low density snow allowing for some loose slides on some steep slopes with little slab avalanche activity noted.  </p>,
#    '\n\n',
#    <p>At mid and lower terrain a still shallow snowcover is limiting the avalanche potential in many to most areas with significant terrain and vegetative anchoring remaining in place.</p>,
#    '\n\n',
#    <p>Over the past week the Pacific Northwest has been in the freezer, under a cold and dry northerly flow aloft. During this dry period there have been periods of strong easterly ridge top winds, mainly last Friday and Saturday that transported loose surface snow and built some small wind slabs. There were some triggered shallow wind slab releases noted, near Crystal Mountain on East peak as well as other area. </p>,
#    '\n\n',
#    <p>The strong east winds shifted to strong west to northwest winds Sunday and continued through Monday. This has been reported to redistribute weak surface snow back to some easterly facing slopes below higher ridges.</p>,
#    '\n\n',
#    <p>The cold dry weather has also been active above and through the surface snow with thick surface hoar growth in many areas as well as producing abundant near surface faceted snow. In addition the cold temperatures and hence strong temperature gradient in the upper snowpack has allowed for the initial good bond of new snow to the crust to begin weakening.   </p>,
#    '\n\n',
#    <p>Photos of near surface facets and surface hoar, Monday 12/09 by WSDOT avalanche forecaster John Stimberis at Snoqualmie Pass:</p>,
#    '\n\n',
#    <p><img alt="Early December facets, Snoqualmie Pass, J. Stimberis" src="/media/uploads/2013/12/10/20131209 facets 5 Stimbuck.jpg" style="width: 300px; height: 300px;"/>    <img alt="" src="/media/uploads/2013/12/10/20131209 facets Stimbuck.jpg" style="width: 400px; height: 299px;"/><img alt="" src="/media/uploads/2013/12/10/20131209 chains Stimbuck.jpg" style="width: 300px; height: 252px;"/></p>,
#    '\n\n            ',
#    <div class="forecast-detailed">
#                    <h2>Detailed Forecast for Wednesday:</h2>
#                    <p>Warmer and drier air moving across the Pacific Northwest Wednesday should allow for some slow settlement of recently formed wind slab in the alpine. Recent strong winds have exposed firm or hard ice crusts and produced a wide variety of snow surfaces at higher elevations.</p>
#
#                </div>,
#    '\n        '],
#   'likelihoods': ['https://d22fgw9k2fjwhz.cloudfront.net/media/images/likelihood_images/likelihood-22.png'],
#   'octagons': ['/avalanche-forecast/octagon/problem/88.png'],
#   'problems': ['wind-slab'],
#   'sizes': ['https://d22fgw9k2fjwhz.cloudfront.net/media/images/size_images/size-11.png'],
#   'treeline-above': 'Moderate',
#   'treeline-below': 'Low',
#   'treeline-near': 'Moderate'},
#  '2:42 PM PST Tuesday, December 10, 2013': {'discussion': ['\n            ',
#    <div class="forecast-snowpack" id="slider1-title" style="display: none">
#                    <h3>Recent images from NWAC:</h3>
#                </div>,
#    '\n            ',
#    ' Jssor Slider Begin ',
#    '\n            ',
#    ' You can move inline styles to css file or css block. ',
#    '\n            ',
#    <div id="slider1_container" style="position: relative; top: 0px; left: 0px; width: 809px; height: 150px; overflow: hidden; display: none;">
#                    <!-- Loading Screen -->
#                    <div style="position: absolute; top: 0px; left: 0px;" u="loading">
#                        <div style="filter: alpha(opacity=70); opacity:0.7; position: absolute; display: block;
#                            background-color: #000; top: 0px; left: 0px; width: 100%;height:100%;">
#                        </div>
#                        <div style="position: absolute; display: block; background: url(../../../static/images/loading.gif) no-repeat center center;
#                            top: 0px; left: 0px;width: 100%;height:100%;">
#                        </div>
#                    </div>
#                    <!-- Slides Container -->
#                    <div id="nwacus_feed" style="cursor: move; position: absolute; left: 0px; top: 0px; width: 809px; height: 150px; overflow: hidden;" u="slides">
#                    </div>
#
#                    <!-- Bullet Navigator Skin Begin -->
#                    <!-- bullet navigator container -->
#                    <div class="jssorb03" style="position: absolute; bottom: 4px; right: 6px;" u="navigator">
#                        <!-- bullet navigator item prototype -->
#                        <div style="position: absolute; width: 21px; height: 21px; text-align:center; line-height:21px; color:white; font-size:12px;" u="prototype">
#                            <div u="numbertemplate"></div>
#                        </div>
#                    </div>
#                    <!-- Bullet Navigator Skin End -->
#                    <!-- Arrow Navigator Skin Begin -->
#                    <!-- Arrow Left -->
#                    <span class="jssora03l" style="width: 55px; height: 55px; top: 123px; left: 8px;" u="arrowleft">
#                    </span>
#                    <!-- Arrow Right -->
#                    <span class="jssora03r" style="width: 55px; height: 55px; top: 123px; right: 8px" u="arrowright">
#                    </span>
#                    <!-- Arrow Navigator Skin End -->
#                </div>,
#    '\n            ',
#    ' Jssor Slider End ',
#    '\n            ',
#    <h2>Snowpack Analysis:</h2>,
#    '\n            ',
#    <p>The last significant rain and snowfall occurred on December 1st and 2nd when most NWAC weather stations recorded 3-5 inches of precipitation and the Mt Hood area received over 10 inches of water. Much of this fell as rain at mid and lower elevations with higher terrain receiving 1-2 feet of snow. </p>,
#    '\n\n',
#    <p>That last warm storm in early December helped form a very strong crust layer with initially very good bonding of the new snow to the forming crust. There was little avalanche activity following this storm with colder low density snow allowing for some loose slides on some steep slopes with little slab avalanche activity noted.  </p>,
#    '\n\n',
#    <p>At mid and lower terrain a still shallow snowcover is limiting the avalanche potential in many to most areas with significant terrain and vegetative anchoring remaining in place.</p>,
#    '\n\n',
#    <p>Over the past week the Pacific Northwest has been in the freezer, under a cold and dry northerly flow aloft. During this dry period there have been periods of strong easterly ridge top winds, mainly last Friday and Saturday, that transported loose surface snow and built some small wind slabs. There were some triggered shallow wind slab releases noted, near Crystal Mountain on East peak as well as other area. </p>,
#    '\n\n',
#    <p>The strong east winds shifted to strong west to northwest winds Sunday and continued through Monday. This has been redistributed weak surface snow back to some easterly facing slopes below higher ridges.</p>,
#    '\n\n',
#    <p>The cold dry weather has also been active above and through the surface snow with thick surface hoar growth in many areas as well as producing abundant near surface faceted snow. In addition, the cold temperatures and hence strong temperature gradient in the upper snowpack, have allowed for the initial good bond of new snow to the crust to begin weakening.   </p>,
#    '\n\n',
#    <p>Photos of near surface facets and surface hoar, Monday 12/09 by WSDOT avalanche forecaster John Stimberis at Snoqualmie Pass:</p>,
#    '\n\n',
#    <p><img alt="Early December facets, Snoqualmie Pass, J. Stimberis" src="/media/uploads/2013/12/10/20131209 facets 5 Stimbuck.jpg" style="width: 300px; height: 300px;"/>    <img alt="" src="/media/uploads/2013/12/10/20131209 facets Stimbuck.jpg" style="width: 400px; height: 299px;"/><img alt="" src="/media/uploads/2013/12/10/20131209 chains Stimbuck.jpg" style="width: 300px; height: 252px;"/></p>,
#    '\n\n            ',
#    <div class="forecast-detailed">
#                    <h2>Detailed Forecast for Wednesday:</h2>
#                    <p>Warmer and drier air moving across the Pacific Northwest Wednesday should allow for some slow settlement of recently formed wind slab in the alpine. Recent strong winds have exposed firm or hard ice crusts and produced a wide variety of snow surfaces at higher elevations.</p>
#
#                </div>,
#    '\n        '],
#   'likelihoods': ['https://d22fgw9k2fjwhz.cloudfront.net/media/images/likelihood_images/likelihood-22.png'],
#   'octagons': ['/avalanche-forecast/octagon/problem/89.png'],
#   'problems': ['wind-slab'],
#   'sizes': ['https://d22fgw9k2fjwhz.cloudfront.net/media/images/size_images/size-11.png'],
#   'treeline-above': 'Moderate',
#   'treeline-below': 'Low',
#   'treeline-near': 'Moderate'},
#  '3:26 PM PST Wednesday, December 11, 2013': {'discussion': ['\n            ',
#    <div class="forecast-snowpack" id="slider1-title" style="display: none">
#                    <h3>Recent images from NWAC:</h3>
#                </div>,
#    '\n            ',
#    ' Jssor Slider Begin ',
#    '\n            ',
#    ' You can move inline styles to css file or css block. ',
#    '\n            ',
#    <div id="slider1_container" style="position: relative; top: 0px; left: 0px; width: 809px; height: 150px; overflow: hidden; display: none;">
#                    <!-- Loading Screen -->
#                    <div style="position: absolute; top: 0px; left: 0px;" u="loading">
#                        <div style="filter: alpha(opacity=70); opacity:0.7; position: absolute; display: block;
#                            background-color: #000; top: 0px; left: 0px; width: 100%;height:100%;">
#                        </div>
#                        <div style="position: absolute; display: block; background: url(../../../static/images/loading.gif) no-repeat center center;
#                            top: 0px; left: 0px;width: 100%;height:100%;">
#                        </div>
#                    </div>
#                    <!-- Slides Container -->
#                    <div id="nwacus_feed" style="cursor: move; position: absolute; left: 0px; top: 0px; width: 809px; height: 150px; overflow: hidden;" u="slides">
#                    </div>
#
#                    <!-- Bullet Navigator Skin Begin -->
#                    <!-- bullet navigator container -->
#                    <div class="jssorb03" style="position: absolute; bottom: 4px; right: 6px;" u="navigator">
#                        <!-- bullet navigator item prototype -->
#                        <div style="position: absolute; width: 21px; height: 21px; text-align:center; line-height:21px; color:white; font-size:12px;" u="prototype">
#                            <div u="numbertemplate"></div>
#                        </div>
#                    </div>
#                    <!-- Bullet Navigator Skin End -->
#                    <!-- Arrow Navigator Skin Begin -->
#                    <!-- Arrow Left -->
#                    <span class="jssora03l" style="width: 55px; height: 55px; top: 123px; left: 8px;" u="arrowleft">
#                    </span>
#                    <!-- Arrow Right -->
#                    <span class="jssora03r" style="width: 55px; height: 55px; top: 123px; right: 8px" u="arrowright">
#                    </span>
#                    <!-- Arrow Navigator Skin End -->
#                </div>,
#    '\n            ',
#    ' Jssor Slider End ',
#    '\n            ',
#    <h2>Snowpack Analysis:</h2>,
#    '\n            ',
#    <p>The last significant rain and snowfall occurred on 1 and 2 December when NWAC weather stations near and west of the crest recorded 3-5 inches of precipitation and the Mt Hood area received over 10 inches of water. Most of the precipitation fell as rain at mid and lower elevations with higher terrain receiving rain  and then 1-2 feet of snow.</p>,
#    '\n\n',
#    <p>The storm at the start of December helped form a generally thick, strong crust with generally cohesionless new snow above the crust. There was little avalanche activity following the storm with colder low density snow allowing for some loose slides on some steep slopes but little slab avalanche activity was noted..</p>,
#    '\n\n',
#    <p>Over the past week the Pacific Northwest has been in the freezer under a cold and dry northerly flow aloft. During this dry period there were strong easterly ridge top winds, mainly last Friday and Saturday, that transported loose surface snow and built some small wind slabs on some lee slopes. A shallow wind slab was triggered on East Peak near Crystal Mountain. </p>,
#    '\n\n',
#    <p>Then the winds shifted to strong west to northwesterly on Sunday and Monday. This redistributed weak loose surface snow back to some easterly facing slopes below higher ridges building additional isolated wind slab.</p>,
#    '\n\n',
#    <p>The cold dry weather has also been active in the surface snow producing thick surface hoar growth in many areas and near surface faceted snow.</p>,
#    '\n\n',
>
#
#                </div>,
#    '\n        '],
#   'likelihoods': ['https://d22fgw9k2fjwhz.cloudfront.net/media/images/likelihood_images/likelihood-33.png',
#    'https://d22fgw9k2fjwhz.cloudfront.net/media/images/likelihood_images/likelihood-22.png'],
#   'octagons': ['/avalanche-forecast/octagon/problem/131.png',
#    '/avalanche-forecast/octagon/problem/132.png'],
#   'problems': ['wind-slab', 'storm-slabs'],
#   'sizes': ['https://d22fgw9k2fjwhz.cloudfront.net/media/images/size_images/size-12.png',
#    'https://d22fgw9k2fjwhz.cloudfront.net/media/images/size_images/size-11.png'],
#   'treeline-above': 'Considerable',
#   'treeline-below': 'Moderate',
#   'treeline-near': 'Moderate'},
#  '9:24 PM PST Tuesday, December 10, 2013': {'discussion': ['\n            ',
#    <div class="forecast-snowpack" id="slider1-title" style="display: none">
#                    <h3>Recent images from NWAC:</h3>
#                </div>,
#    '\n            ',
#    ' Jssor Slider Begin ',
#    '\n            ',
#    ' You can move inline styles to css file or css block. ',
#    '\n            ',
#    <div id="slider1_container" style="position: relative; top: 0px; left: 0px; width: 809px; height: 150px; overflow: hidden; display: none;">
#                    <!-- Loading Screen -->
#                    <div style="position: absolute; top: 0px; left: 0px;" u="loading">
#                        <div style="filter: alpha(opacity=70); opacity:0.7; position: absolute; display: block;
#                            background-color: #000; top: 0px; left: 0px; width: 100%;height:100%;">
#                        </div>
#                        <div style="position: absolute; display: block; background: url(../../../static/images/loading.gif) no-repeat center center;
#                            top: 0px; left: 0px;width: 100%;height:100%;">
#                        </div>
#                    </div>
#                    <!-- Slides Container -->
#                    <div id="nwacus_feed" style="cursor: move; position: absolute; left: 0px; top: 0px; width: 809px; height: 150px; overflow: hidden;" u="slides">
#                    </div>
#
#                    <!-- Bullet Navigator Skin Begin -->
#                    <!-- bullet navigator container -->
#                    <div class="jssorb03" style="position: absolute; bottom: 4px; right: 6px;" u="navigator">
#                        <!-- bullet navigator item prototype -->
#                        <div style="position: absolute; width: 21px; height: 21px; text-align:center; line-height:21px; color:white; font-size:12px;" u="prototype">
#                            <div u="numbertemplate"></div>
#                        </div>
#                    </div>
#                    <!-- Bullet Navigator Skin End -->
#                    <!-- Arrow Navigator Skin Begin -->
#                    <!-- Arrow Left -->
#                    <span class="jssora03l" style="width: 55px; height: 55px; top: 123px; left: 8px;" u="arrowleft">
#                    </span>
#                    <!-- Arrow Right -->
#                    <span class="jssora03r" style="width: 55px; height: 55px; top: 123px; right: 8px" u="arrowright">
#                    </span>
#                    <!-- Arrow Navigator Skin End -->
#                </div>,
#    '\n            ',
#    ' Jssor Slider End ',
#    '\n            ',
#    <h2>Snowpack Analysis:</h2>,
#    '\n            ',
#    <p>The last significant rain and snowfall occurred on December 1st and 2nd when most NWAC weather stations recorded 3-5 inches of precipitation and the Mt Hood area received over 10 inches of water. Most of the precipitation fell as rain at mid and lower elevations with higher terrain receiving rain then 1-2 feet of snow. </p>,
#    '\n\n',
#    <p>That last warm storm in early December helped form a very thick and strong crust layer with initially very good bonding of the new snow to the forming crust. There was little avalanche activity following this storm with colder low density snow allowing for some loose slides on some steep slopes but little slab avalanche activity was noted.  </p>,
#    '\n\n',
#    <p>At mid and lower terrain a still shallow snowcover is limiting the avalanche potential in many to most areas with significant terrain and vegetative anchoring remaining in place.</p>,
#    '\n\n',
#    <p>Over the past week the Pacific Northwest has been in the freezer, under a cold and dry northerly flow aloft. During this dry period there have been periods of strong easterly ridge top winds, mainly last Friday and Saturday, that transported loose surface snow and built some small wind slabs on some lee slopes. There were some triggered shallow wind slab releases noted, mainly near Crystal Mountain on East peak. </p>,
#    '\n\n',
#    <p>The strong east winds shifted to strong west to northwest winds Sunday, continuing through Monday. This has again redistributed weak loose surface snow back to some easterly facing slopes below higher ridges building additional but isolated wind slab.</p>,
#    '\n\n',
#    <p>The cold dry weather has also been active above and through the surface snow with thick surface hoar growth in many areas as well as producing abundant near surface faceted snow. In addition, the cold temperatures and hence strong temperature gradient in the upper snowpack, have allowed for the initial good bond of new snow to the crust to begin weakening.   </p>,
#    '\n\n',
#    <p>Photos of near surface facets and surface hoar, Monday 12/09 by WSDOT avalanche forecaster John Stimberis at Snoqualmie Pass:</p>,
#    '\n\n',
#    <p><img alt="Early December facets, Snoqualmie Pass, J. Stimberis" src="/media/uploads/2013/12/10/20131209 facets 5 Stimbuck.jpg" style="width: 300px; height: 300px;"/>    <img alt="" src="/media/uploads/2013/12/10/20131209 facets Stimbuck.jpg" style="width: 400px; height: 299px;"/><img alt="" src="/media/uploads/2013/12/10/20131209 chains Stimbuck.jpg" style="width: 300px; height: 252px;"/></p>,
#    '\n\n            ',
#    <div class="forecast-detailed">
#                    <h2>Detailed Forecast for Wednesday:</h2>
#                    <p>Warmer and drier air moving across the Pacific Northwest Wednesday should allow for some slow settlement of recently formed wind slab in the alpine. Recent strong winds have exposed firm or hard ice crusts and produced a wide variety of snow surfaces at higher elevations.</p>
#
#                </div>,
#    '\n        '],
#   'likelihoods': ['https://d22fgw9k2fjwhz.cloudfront.net/media/images/likelihood_images/likelihood-22.png'],
#   'octagons': ['/avalanche-forecast/octagon/problem/90.png'],
#   'problems': ['wind-slab'],
#   'sizes': ['https://d22fgw9k2fjwhz.cloudfront.net/media/images/size_images/size-11.png'],
#   'treeline-above': 'Moderate',
#   'treeline-below': 'Low',
#   'treeline-near': 'Moderate'}}

# %%
df = pd.DataFrame.from_dict(data, orient='index')
df.head()
# Out:
#                                          treeline-above treeline-below  \
# 2:36 PM PST Tuesday, December 10, 2013         Moderate            Low
# 2:42 PM PST Tuesday, December 10, 2013         Moderate            Low
# 3:26 PM PST Wednesday, December 11, 2013           High   Considerable
# 9:24 PM PST Tuesday, December 10, 2013         Moderate            Low
#
#                                          treeline-near  \
# 2:36 PM PST Tuesday, December 10, 2013        Moderate
# 2:42 PM PST Tuesday, December 10, 2013        Moderate
# 3:26 PM PST Wednesday, December 11, 2013          High
# 9:24 PM PST Tuesday, December 10, 2013        Moderate
#
#                                                                                 problems
# 2:36 PM PST Tuesday, December 10, 2013                            [[problem, wind-slab]]
# 2:42 PM PST Tuesday, December 10, 2013                            [[problem, wind-slab]]
# 3:26 PM PST Wednesday, December 11, 2013  [[problem, wind-slab], [problem, storm-slabs]]
# 9:24 PM PST Tuesday, December 10, 2013                            [[problem, wind-slab]]

# %%
df.to_csv('nwac_mount_hood_problems.csv')

# %%
len(df)
# Out:
# 164
